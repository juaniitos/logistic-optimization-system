# %% [markdown]
# # Desarrollo de Modelos de Machine Learning
#
# Notebook para desarrollo y entrenamiento de modelos predictivos para el sistema logístico.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from prophet import Prophet
import joblib

# %% [markdown]
# ## 1. Preparación de Datos

# %%
# Cargar datos históricos
# df = pd.read_csv('../data/processed/demand_history.csv')
# df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# ## 2. Modelo de Predicción de Demanda con Prophet

# %%
# Preparar datos para Prophet
# prophet_df = df[['date', 'demand']].rename(columns={'date': 'ds', 'demand': 'y'})

# Entrenar modelo
# model = Prophet(
#     yearly_seasonality=True,
#     weekly_seasonality=True,
#     daily_seasonality=False
# )
# model.fit(prophet_df)

# %% [markdown]
# ## 3. Predicciones

# %%
# Hacer predicciones para 30 días
# future = model.make_future_dataframe(periods=30)
# forecast = model.predict(future)

# %% [markdown]
# ## 4. Evaluación del Modelo

# %%
# Calcular métricas
# mae = mean_absolute_error(y_true, y_pred)
# rmse = np.sqrt(mean_squared_error(y_true, y_pred))
# print(f'MAE: {mae:.2f}')
# print(f'RMSE: {rmse:.2f}')

# %% [markdown]
# ## 5. Guardar Modelo

# %%
# Guardar modelo entrenado
# joblib.dump(model, '../data/models/demand_forecast_model.pkl')
# print('Modelo guardado exitosamente')
